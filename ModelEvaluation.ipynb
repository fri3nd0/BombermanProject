# %%
import numpy as np
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ## Basic Agent

# %% [markdown]
# ### Pre Training

# %%
basic_pre_losses = np.array([318.752, 128.109, 120.316, 109.717, 106.748, 
                            100.977, 102.720, 96.309, 100.961, 96.255])
plt.plot(basic_pre_losses, marker = "+")
plt.title("Basic Agent Pre-Training Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.savefig("eval_pics/basic_pre_losses.png", dpi=200)

# %%
with open('Evaluation/Basic/s1_basic.json') as f:
    s1_basic = json.load(f)

s1_basic_scores = s1_basic["by_agent"]["s1_basic_agent"]["scores"]
#print(len(d["by_agent"]['rule_based_agent_0']["scores"]))
plt.hist(s1_basic_scores)
print(np.mean(s1_basic_scores))
print(np.std(s1_basic_scores)/np.sqrt(199))
plt.title("Basic Agent Pre-Trained Scores")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.savefig("eval_pics/basic_pre_scores.png", dpi=200)
plt.show()
# Out:
# 1.725
# 0.11732733491215054

# %% [markdown]
# ### Fine Tuning

# %%
basic_fine_losses = np.array([102.332, 95.647, 95.899, 93.526, 85.886, 93.683,
                             86.340, 89.819, 88.642, 90.694])
plt.plot(basic_fine_losses, marker = "+")
plt.title("Basic Agent Fine-Tuned Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.savefig("eval_pics/basic_fine_losses.png", dpi=200)

# %%
with open('Evaluation/Basic/s2_basic.json') as f:
    s2_basic = json.load(f)

s2_basic_scores = s2_basic["by_agent"]["s2_basic_agent"]["scores"]

plt.hist(s2_basic_scores)
print(np.mean(s2_basic_scores))
print(np.std(s2_basic_scores)/np.sqrt(199))
plt.title("Basic Agent Fine-Tuned Scores")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.savefig("eval_pics/basic_fine_scores.png", dpi=200)

plt.show()
# Out:
# 2.225
# 0.15260510012091527

# %% [markdown]
# ### Self Play

# %%
basic_self_losses = np.array([89.039, 88.845, 88.579, 86.478, 85.569, 87.457,
                             87.691, 86.964, 80.833, 86.640, 83.250, 84.662, 
                             81.650, 83.787, 82.228, 83.297, 79.986, 86.051,
                             82.996, 82.551])
plt.plot(basic_self_losses, marker = "+")
plt.title("Basic Agent Self-Played Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.savefig("eval_pics/basic_self_losses.png", dpi=200)

# %%
with open('Evaluation/Basic/s3_basic.json') as f:
    s3_basic = json.load(f)

s3_basic_scores = s3_basic["by_agent"]["s3_basic_agent"]["scores"]

plt.hist(s3_basic_scores)
print(np.mean(s3_basic_scores))
print(np.std(s3_basic_scores)/np.sqrt(199))
plt.title("Basic Agent Self-Played Scores")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.savefig("eval_pics/basic_self_scores.png", dpi=200)

plt.show()
# Out:
# 2.295
# 0.17113242396653916

# %% [markdown]
# ## LFOV Agent

# %% [markdown]
# ### Pre Training

# %%
lfov_pre_losses = np.array([271.523, 118.307, 111.844, 102.938, 102.070, 101.376, 93.473, 95.278, 90.847,
                  92.429])
plt.plot(lfov_pre_losses, marker = "+")
plt.title("Large Agent Pre-Training Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.savefig("eval_pics/lfov_pre_losses.png", dpi=200)

# %%
with open('Evaluation/Large/s1_lfov.json') as f:
    s1_lfov = json.load(f)

s1_lfov_scores = s1_lfov["by_agent"]["s1_lfov_agent"]["scores"]

plt.hist(s1_lfov_scores)
print(np.mean(s1_lfov_scores))
print(np.std(s1_lfov_scores)/np.sqrt(199))
plt.title("Large Agent Pre-Trained Scores")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.savefig("eval_pics/lfov_pre_scores.png", dpi=200)

plt.show()
# Out:
# 2.205
# 0.148577425123339

# %% [markdown]
# ### Fine Tuning

# %%
lfov_fine_losses = np.array([91.364, 92.761, 87.313, 86.266, 91.453, 86.538, 81.298,
                       84.761, 87.836, 83.702])
plt.plot(lfov_fine_losses, marker = "+")
plt.title("Large Agent Fine-Tuning Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.savefig("eval_pics/lfov_fine_losses.png", dpi=200)

# %%
with open('Evaluation/Large/s2_lfov.json') as f:
    s2_lfov = json.load(f)

s2_lfov_scores = s2_lfov["by_agent"]["s2_lfov_agent"]["scores"]

plt.hist(s2_lfov_scores)
print(np.mean(s2_lfov_scores))
print(np.std(s2_lfov_scores)/np.sqrt(199))
plt.title("Large Agent Fine-Tuned Scores")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.savefig("eval_pics/lfov_fine_scores.png", dpi=200)

plt.show()
# Out:
# 2.44
# 0.1681468609108444

# %% [markdown]
# ### Self Play

# %%
lfov_self_losses = np.array([93.594, 83.185, 84.440, 79.566, 80.779, 82.561, 80.875,
                       81.135, 80.564, 79.371, 78.615, 76.943, 79.963, 78.516, 77.611,
                       77.549, 77.975, 78.883, 78.297, 76.469])
plt.plot(lfov_self_losses, marker = "+")
plt.title("Large Agent Self Play Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.savefig("eval_pics/lfov_self_losses.png", dpi=200)

# %%
with open('Evaluation/Large/s3_lfov.json') as f:
    s3_lfov = json.load(f)

s3_lfov_scores = s3_lfov["by_agent"]["s3_lfov_agent"]["scores"]

plt.hist(s3_lfov_scores)
print(np.mean(s3_lfov_scores))
print(np.std(s3_lfov_scores)/np.sqrt(199))
plt.title("Large Agent Self-Played Scores")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.savefig("eval_pics/lfov_self_scores.png", dpi=200)

plt.show()
# Out:
# 2.42
# 0.13549833576459483

# %% [markdown]
# ## XXL LFOV Agent

# %% [markdown]
# ### Pre Training

# %%
xxl_lfov_pre_losses = np.array([324.458, 130.920, 108.114, 104.714, 101.790, 
                               101.170, 97.962, 100.556])

plt.plot(xxl_lfov_pre_losses, marker = "+")
plt.title("XXL Agent Pre-Training Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.savefig("eval_pics/xxl_pre_losses.png", dpi=200)

# %%
with open('Evaluation/XXL/s1_xxl_lfov.json') as f:
    s1_xxl_lfov = json.load(f)

s1_xxl_lfov_scores = s1_xxl_lfov["by_agent"]["s1_xxl_lfov_agent"]["scores"]

plt.hist(s1_xxl_lfov_scores)
print(np.mean(s1_xxl_lfov_scores))
print(np.std(s1_xxl_lfov_scores)/np.sqrt(199))
plt.title("XXL Agent Pre-Trained Scores")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.savefig("eval_pics/xxl_pre_scores.png", dpi=200)

plt.show()
# Out:
# 1.475
# 0.13707964526408958

# %% [markdown]
# ### Fine Tuning

# %%
xxl_lfov_fine_losses = np.array([95.510, 87.619, 84.072, 84.104, 81.594,
                                85.042, 78.654, 86.343, 86.047, 83.555])

plt.plot(xxl_lfov_fine_losses, marker = "+")
plt.title("XXL Agent Fine-Tuning Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.savefig("eval_pics/xxl_fine_losses.png", dpi=200)

# %%
with open('Evaluation/XXL/s2_xxl_lfov.json') as f:
    s2_xxl_lfov = json.load(f)

s2_xxl_lfov_scores = s2_xxl_lfov["by_agent"]["s2_xxl_lfov_agent"]["scores"]

plt.hist(s2_xxl_lfov_scores)
print(np.mean(s2_xxl_lfov_scores))
print(np.std(s2_xxl_lfov_scores)/np.sqrt(199))
#print(np.std(s2_xxl_lfov_scores))
plt.title("XXL Agent Fine-Tuned Scores")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.savefig("eval_pics/xxl_fine_scores.png", dpi=200)

plt.show()
# Out:
# 1.555
# 0.14505197474313963

# %% [markdown]
# ### Self Play

# %%
xxl_lfov_self_losses = np.array([92.018, 80.814, 77.365, 77.675, 77.074, 77.590,
                                73.271, 73.507, 78.866, 75.060, 73.690, 73.025,
                                 70.834, 71.353, 75.419, 73.606, 69.732, 74.796, 
                                73.953, 70.363])


plt.plot(xxl_lfov_self_losses, marker = "+")
plt.title("XXL Agent Self Play Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.savefig("eval_pics/xxl_self_losses.png", dpi=200)

# %%
with open('Evaluation/XXL/s3_xxl_lfov.json') as f:
    s3_xxl_lfov = json.load(f)

s3_xxl_lfov_scores = s3_xxl_lfov["by_agent"]["s3_xxl_lfov_agent"]["scores"]

plt.hist(s3_xxl_lfov_scores)
print(np.mean(s3_xxl_lfov_scores))
print(np.std(s3_xxl_lfov_scores)/np.sqrt(199))
plt.title("XXL Agent Self-Played Scores")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.savefig("eval_pics/xxl_self_scores.png", dpi=200)

plt.show()
# Out:
# 2.555
# 0.1672565357279607

# %% [markdown]
# ## Handcrafted Agent
# ### Pre Training

# %%
hc_losses_pre = np.load("losses_pre.npy")
plt.plot(hc_losses_pre, marker = "+")
plt.title("Handcrafted Agent Pre Training Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.savefig("eval_pics/hand_pre_losses.png", dpi=200)

# %%
with open('Evaluation/hand_crafted/handprevrule.json') as f:
    hand_pre = json.load(f)

hand_pre_scores = hand_pre["by_agent"]["hand_crafted_agent"]["scores"]

plt.hist(hand_pre_scores)
print(np.mean(hand_pre_scores))
print(np.std(hand_pre_scores)/np.sqrt(199))
plt.title("Handcrafted Agent Pre-Trained Scores")
plt.xlabel("Score")
plt.savefig("eval_pics/hand_pre_scores.png", dpi=200)
plt.show()
# Out:
# 1.46
# 0.1122721030605027

# %% [markdown]
# ### Fine Tuning

# %%
hc_losses_fine = np.load("losses_fine.npy")
plt.plot(hc_losses_fine, marker = "+")
plt.title("Handcrafted Agent Fine-Tuning Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.savefig("eval_pics/hand_fine_losses.png", dpi=200)

# %%
with open('Evaluation/hand_crafted/handfinevrule.json') as f:
    hand_fine = json.load(f)

hand_fine_scores = hand_fine["by_agent"]["hand_crafted_agent"]["scores"]

plt.hist(hand_fine_scores)
print(np.mean(hand_fine_scores))
print(np.std(hand_fine_scores)/np.sqrt(199))
plt.title("Handcrafted Agent Fine-Tuned Scores")
plt.xlabel("Score")
plt.savefig("eval_pics/hand_fine_scores.png", dpi=200)
plt.show()
# Out:
# 1.28
# 0.1167310183852875

# %% [markdown]
# ## Extras

# %% [markdown]
# ### Classic vs Loot-Crate
# #### Classic

# %%
with open('Evaluation/classic vs lootcrate/rulebasedclassic.json') as f:
    classic = json.load(f)

classic_scores_0 = classic["by_agent"]["rule_based_agent_0"]["scores"]

plt.hist(classic_scores_0)
print(np.mean(classic_scores_0))
print(np.std(classic_scores_0))
print(np.std(classic_scores_0)/np.mean(classic_scores_0)/np.sqrt(199))

plt.title("Rule-Based Agent 0 Scores Classic Scenario")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.savefig("eval_pics/classic_0_scores.png", dpi=200)

plt.show()
# Out:
# 3.125
# 2.5728146066127655
# 0.058362237395158556

# %%
with open('Evaluation/classic vs lootcrate/rulebasedclassic.json') as f:
    classic = json.load(f)

classic_scores_1 = classic["by_agent"]["rule_based_agent_1"]["scores"]

plt.hist(classic_scores_1)
print(np.mean(classic_scores_1))
print(np.std(classic_scores_1))
print(np.std(classic_scores_1)/np.mean(classic_scores_1)/np.sqrt(199))

plt.title("Rule-Based Agent 1 Scores Classic Scenario")
plt.xlabel("Score")
#plt.xticks(range(0,15))
plt.show()
# Out:
# 2.775
# 2.2123234392827826
# 0.056514396594845584

# %%
with open('Evaluation/classic vs lootcrate/rulebasedclassic.json') as f:
    classic = json.load(f)

classic_scores_2 = classic["by_agent"]["rule_based_agent_2"]["scores"]

plt.hist(classic_scores_2)
print(np.mean(classic_scores_2))
print(np.std(classic_scores_2))
print(np.std(classic_scores_2)/np.mean(classic_scores_2)/np.sqrt(199))

plt.title("Rule-Based Agent 2 Scores Classic Scenario")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.show()
# Out:
# 2.875
# 2.479793338163485
# 0.061143613555790434

# %%
with open('Evaluation/classic vs lootcrate/rulebasedclassic.json') as f:
    classic = json.load(f)

classic_scores_3 = classic["by_agent"]["rule_based_agent_3"]["scores"]

plt.hist(classic_scores_3)
print(np.mean(classic_scores_3))
print(np.std(classic_scores_3))
print(np.std(classic_scores_3)/np.mean(classic_scores_3)/np.sqrt(199))

plt.title("Rule-Based Agent 3 Scores Classic Scenario")
plt.xlabel("Score")
plt.xticks(range(0,15))
plt.show()
# Out:
# 2.87
# 2.484572397818184
# 0.06136817683957508

# %% [markdown]
# #### Loot-Crate

# %%
with open('Evaluation/classic vs lootcrate/rulebasedlootcrate.json') as f:
    classic = json.load(f)

lc_scores_0 = classic["by_agent"]["rule_based_agent_0"]["scores"]

plt.hist(lc_scores_0)
print(np.mean(lc_scores_0))
print(np.std(lc_scores_0))
print(np.std(lc_scores_0)/np.mean(lc_scores_0)/np.sqrt(199))
plt.title("Rule-Based Agent 0 Scores Loot-Crate Scenario")
plt.xlabel("Score")
plt.xticks(np.array(range(0,15))*2)
plt.savefig("eval_pics/loot_0_scores.png", dpi=200)

plt.show()
# Out:
# 11.365
# 5.115835708855397
# 0.031909544935486915

# %%
with open('Evaluation/classic vs lootcrate/rulebasedlootcrate.json') as f:
    classic = json.load(f)

lc_scores_1 = classic["by_agent"]["rule_based_agent_1"]["scores"]

plt.hist(lc_scores_1)
print(np.mean(lc_scores_1))
print(np.std(lc_scores_1))
print(np.std(lc_scores_1)/np.mean(lc_scores_1)/np.sqrt(199))
plt.title("Rule-Based Agent 1 Scores Loot-Crate Scenario")
plt.xlabel("Score")
plt.xticks(np.array(range(0,15))*2)
plt.show()
# Out:
# 12.325
# 4.930453833066485
# 0.02835785845372932

# %%
with open('Evaluation/classic vs lootcrate/rulebasedlootcrate.json') as f:
    classic = json.load(f)

lc_scores_2 = classic["by_agent"]["rule_based_agent_2"]["scores"]

plt.hist(lc_scores_2)
print(np.mean(lc_scores_2))
print(np.std(lc_scores_2))
print(np.std(lc_scores_2)/np.mean(lc_scores_2)/np.sqrt(199))
plt.title("Rule-Based Agent 2 Scores Loot-Crate Scenario")
plt.xlabel("Score")
plt.xticks(np.array(range(0,15))*2)
plt.show()
# Out:
# 12.525
# 5.248749851155035
# 0.029706507938316206

# %%
with open('Evaluation/classic vs lootcrate/rulebasedlootcrate.json') as f:
    classic = json.load(f)

lc_scores_3 = classic["by_agent"]["rule_based_agent_3"]["scores"]

plt.hist(lc_scores_3)
print(np.mean(lc_scores_3))
print(np.std(lc_scores_3))
print(np.std(lc_scores_3)/np.mean(lc_scores_3)/np.sqrt(199))
plt.title("Rule-Based Agent 3 Scores Loot-Crate Scenario")
plt.xlabel("Score")
#plt.xticks(np.array(range(0,15))*2)
plt.show()
# Out:
# 12.0
# 5.321653878260029
# 0.03143683678215211

# %% [markdown]
# ### Alle Gegen Alle

# %%
with open('Evaluation/allegegenalle/allvall.json') as f:
    allvall = json.load(f)

hc = allvall["by_agent"]["hand_crafted_agent"]["scores"]

plt.hist(hc)
print(np.mean(hc))
print(np.std(hc)/np.sqrt(199))
print(np.std(hc)/np.mean(hc))
plt.title("Hand-Crafted Agent Scores vs Other Trained Agents")
plt.xlabel("Score")
plt.xticks(np.array(range(0,15)))
plt.savefig("eval_pics/allvall_hand_scores.png", dpi=200)

plt.show()
# Out:
# 1.585
# 0.14480579613042024
# 1.2887931446922158

# %%
basic = allvall["by_agent"]["s3_basic_agent"]["scores"]

plt.hist(basic)
print(np.mean(basic))
print(np.std(basic)/np.sqrt(199))
print(np.std(basic)/np.mean(basic))
plt.title("Basic Agent Scores vs Other Trained Agents")
plt.xlabel("Score")
plt.xticks(np.array(range(0,15)))
plt.savefig("eval_pics/allvall_basic_scores.png", dpi=200)

plt.show()
# Out:
# 2.315
# 0.16080474442361997
# 0.9798834012361368

# %%
lfov = allvall["by_agent"]["s3_lfov_agent"]["scores"]

plt.hist(lfov)
print(np.mean(lfov))
print(np.std(lfov)/np.sqrt(199))
print(np.std(lfov)/np.mean(lfov))
plt.title("Large Agent Scores vs Other Trained Agents")
plt.xlabel("Score")
plt.xticks(np.array(range(0,15)))
plt.savefig("eval_pics/allvall_large_scores.png", dpi=200)

plt.show()
# Out:
# 2.685
# 0.1640531688540495
# 0.8619198285480903

# %%
xxl = allvall["by_agent"]["s3_xxl_lfov_agent"]["scores"]

plt.hist(xxl)
print(np.mean(xxl))
print(np.std(xxl)/np.sqrt(199))
print(np.std(xxl)/np.mean(xxl))
plt.title("XXL Agent Scores vs Other Trained Agents")
plt.xlabel("Score")
plt.xticks(np.array(range(0,15)))
plt.savefig("eval_pics/allvall_xxl_scores.png", dpi=200)

plt.show()
# Out:
# 3.33
# 0.16550668358576276
# 0.7011288553196566

# %% [markdown]
# #### weak

# %%
with open('Evaluation/allegegenalle/weakallvall.json') as f:
    weakallvall = json.load(f)

weakhc = weakallvall["by_agent"]["hand_crafted_agent"]["scores"]

plt.hist(weakhc)
print(np.mean(weakhc))
print(np.std(weakhc)/np.sqrt(199))
print(np.std(weakhc)/np.mean(weakhc))
plt.title("Hand-Crafted Agent Scores vs Other Trained Agents (Pre-trained)")
plt.xlabel("Score")
plt.xticks(np.array(range(0,15)))
plt.savefig("eval_pics/weakallvall_hand_scores.png", dpi=200)

plt.show()
# Out:
# 1.935
# 0.15271043640476795
# 1.1133053269775808

# %%
with open('Evaluation/allegegenalle/weakallvall.json') as f:
    weakallvall = json.load(f)

weakbasic = weakallvall["by_agent"]["s1_basic_agent"]["scores"]

plt.hist(weakbasic)
print(np.mean(weakbasic))
print(np.std(weakbasic)/np.sqrt(199))
print(np.std(weakbasic)/np.mean(weakbasic))
plt.title("Basic Agent Scores vs Other Trained Agents (Pre-trained)")
plt.xlabel("Score")
plt.xticks(np.array(range(0,15)))
plt.savefig("eval_pics/weakallvall_basic_scores.png", dpi=200)

plt.show()
# Out:
# 2.6
# 0.17636759236943436
# 0.9569119465095945

# %%
weaklarge = weakallvall["by_agent"]["s1_lfov_agent"]["scores"]

plt.hist(weaklarge)
print(np.mean(weaklarge))
print(np.std(weaklarge)/np.sqrt(199))
print(np.std(weaklarge)/np.mean(weaklarge))
plt.title("Large Agent Scores vs Other Trained Agents (Pre-trained)")
plt.xlabel("Score")
plt.xticks(np.array(range(0,15)))
plt.savefig("eval_pics/weakallvall_large_scores.png", dpi=200)

plt.show()
# Out:
# 2.875
# 0.2038495725803859
# 1.0002268173771278

# %%
weakxxl = weakallvall["by_agent"]["s1_xxl_lfov_agent"]["scores"]

plt.hist(weakxxl)
print(np.mean(weakxxl))
print(np.std(weakxxl)/np.sqrt(199))
print(np.std(weakxxl)/np.mean(weakxxl))
plt.title("XXL Agent Scores vs Other Trained Agents (Pre-trained)")
plt.xlabel("Score")
plt.xticks(np.array(range(0,15)))
plt.savefig("eval_pics/weakallvall_xxl_scores.png", dpi=200)

plt.show()
# Out:
# 2.87
# 0.1842150262041536
# 0.905460884372553

# %% [markdown]
# ## MasterBlaster

# %%
with open('Evaluation/masterblastervall.json') as f:
    mb = json.load(f)

mbscore = mb["by_agent"]["MasterBlaster"]["scores"]

plt.hist(mbscore)
print(np.mean(mbscore))
print(np.std(mbscore)/np.sqrt(499))
print(np.std(mbscore)/np.mean(mbscore))
plt.title("MasterBlaster Agent Scores vs Other Trained Agents")
plt.xlabel("Score")
#plt.xticks(np.array(range(0,15)))
#plt.savefig("eval_pics/masterblastervall_scores.png", dpi=200)

plt.show()
# Out:
# 3.052
# 0.11529604657885469
# 0.8438789608638556

# %%
lfovscore = mb["by_agent"]["s3_lfov_agent"]["scores"]

plt.hist(lfovscore)
print(np.mean(lfovscore))
print(np.std(lfovscore)/np.sqrt(499))
print(np.std(lfovscore)/np.mean(lfovscore))
plt.title("Large Agent Scores vs Other Trained Agents and MasterBlaster")
plt.xlabel("Score")
#plt.xticks(np.array(range(0,15)))
#plt.savefig("eval_pics/masterblastervall_scores.png", dpi=200)

plt.show()
# Out:
# 2.742
# 0.10791739585746736
# 0.8791728726580462

# %%
xxlscore = mb["by_agent"]["s3_xxl_lfov_agent"]["scores"]

plt.hist(xxlscore)
print(np.mean(xxlscore))
print(np.std(xxlscore)/np.sqrt(499))
print(np.std(xxlscore)/np.mean(xxlscore))
plt.title("XXL Agent Scores vs Other Trained Agents and MasterBlaster")
plt.xlabel("Score")
#plt.xticks(np.array(range(0,15)))
#plt.savefig("eval_pics/masterblastervall_scores.png", dpi=200)

plt.show()
# Out:
# 2.888
# 0.11030524236402355
# 0.8531968377141835

# %%
basicscore = mb["by_agent"]["s3_basic_agent"]["scores"]

plt.hist(basicscore)
print(np.mean(basicscore))
print(np.std(basicscore)/np.sqrt(499))
print(np.std(basicscore)/np.mean(basicscore))
plt.title("Basic Agent Scores vs Other Trained Agents and MasterBlaster")
plt.xlabel("Score")
#plt.xticks(np.array(range(0,15)))
#plt.savefig("eval_pics/masterblastervall_scores.png", dpi=200)

plt.show()
# Out:
# 2.448
# 0.10203634073044426
# 0.9310944430565172
